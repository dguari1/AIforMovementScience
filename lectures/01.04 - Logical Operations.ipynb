# %% [markdown]
# ## If working in Google Colab, Run this first
# Run the cell below, at the start of every session.
# It downloads the course files to your Google Drive and keeps them up to date.
# When you see \"Setup complete\", you are ready to run the rest of the notebook.
#
# **Do not edit or save your work inside the `AIforMovementScience` folder.**
# Use **File > Save a copy in Drive** and work on your own copy.

# %%
# [course-setup] Run this cell first, every session (or use Runtime > Run all)
import os
os.chdir('/content')                      # start from a valid directory
from google.colab import drive
drive.mount('/content/drive')

REPO = '/content/drive/MyDrive/AIforMovementScience'
if os.path.isdir(REPO + '/.git'):
    # already downloaded before: just update it
    # !git -C "$REPO" fetch origin main && git -C "$REPO" reset --hard origin/main
else:
    # first time, or a broken/partial copy: download a fresh copy
    # !rm -rf "$REPO"
    # !git clone https://github.com/dguari1/AIforMovementScience.git "$REPO"

os.chdir(REPO)
print('Setup complete. You can now run the rest of the notebook.')

# %% [markdown]
# ## Logic Operations
#
# Python can use **Comparison operators** to compare two statements and provide an answer as True (1) or False (0).
# Here are the symbols used by Python to denote logical operations between values or variables
#
# <div>
# <img src="images/LOGIC_Symbols.png" width="200"/>
# </div>

# %%
1>0
# Out:
# True

# %%
1<0
# Out:
# False

# %% [markdown]
# Python can also perform logical operations. The fundamental logical operators are **not**, **and**, and **or**

# %% [markdown]
# ## NOT Operation
# <div>
# <img src="images/NOT_Table.png" width="200"/>
# </div>

# %% [markdown]
# # AND Operation
# <div>
# <img src="images/AND_Table.png" width="200"/>
# </div>

# %% [markdown]
# # OR Operation
# <div>
# <img src="images/OR_Table.png" width="200"/>
# </div>

# %%
(1 > 0), not(1 > 0)
# Out:
# (True, False)

# %%
(1 < 0), not(1 < 0)
# Out:
# True

# %%
(1 > 0), (2 == 3),
# Out:
# (True, False)

# %%
#you can combine multiple operations 
((1 > 0) or (2 == 3))
# Out:
# True

# %%
(1>0), (2==3), ((1>0) and (2==3))
# Out:
# (True, False, False)

# %%
(not (1>0)) or (2==3)
# Out:
# False

# %%
(5+3) > (3+5)
# Out:
# False

# %% [markdown]
# You can also work with True and False statements directly. For example

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True, True or False, False or True, False or False
# Out:
# (True, True, True, False)

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False
