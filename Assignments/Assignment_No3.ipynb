# %% [markdown]
# # APK 6725 — AI for Sport & Movement Sciences
# ## Assignment 3: Loops and Data Structures
#
# This assignment assesses your ability to use **loops** to solve programming problems. Some questions also use lists and dictionaries. Write your code in the cells provided and test it.

# %% [markdown]
# ## Run this first
#
# Run the cell below, at the start of every session. It downloads the course files to your Google Drive and keeps them up to date. When you see "Setup complete", you are ready to work.
#
# **Do not edit or save your work inside the `AIforMovementScience` folder.** Use **File > Save a copy in Drive** and work on your own copy.

# %%
# [course-setup] Run this cell first, every session (or use Runtime > Run all)
import os, sys
os.chdir('/content')                      # start from a valid directory
from google.colab import drive
drive.mount('/content/drive')

REPO = '/content/drive/MyDrive/AIforMovementScience'
if os.path.isdir(REPO + '/.git'):
    # already downloaded before: just update it
    # !git -C "$REPO" fetch origin main && git -C "$REPO" reset --hard origin/main
else:
    # first time, or a broken/partial copy: download a fresh copy
    # !rm -rf "$REPO"
    # !git clone https://github.com/dguari1/AIforMovementScience.git "$REPO"

WORKDIR = REPO + '/Assignments'          # this notebook's folder in the course files
os.chdir(WORKDIR)
sys.path.insert(0, WORKDIR)           # so local .py files (e.g. FunctionExamples.py) import correctly
print('Setup complete. You can now run the rest of the notebook.')

# %% [markdown]
# ## How to submit
#
# Before you submit, please make sure your notebook is organized and reproducible. Part of your grade is for this.
#
# - Answer each question in its own section, using the headings already provided.
# - Put your code in the code cells; when a question asks for a written answer, use the markdown answer cell.
# - Delete any scratch or experimental cells that are not part of your answer.
# - Download your notebook: **File > Download > Download .ipynb**, name it `YourName_Assignment_3.ipynb`, and upload it to Canvas.

# %% [markdown]
# ## Question 1 (0.5 points)
#
# Create a function that prints the following pattern for a given input `n`. For example, for `n = 5` it should print:
#
# ```
# 1
# 22
# 333
# 4444
# 55555
# 4444
# 333
# 22
# 1
# ```
#
# Your program should ask for a user input, verify that the input is an integer, and then print the pattern.

# %%
# Write your code here

# %%
# Test your code here

# %% [markdown]
# ## Question 2 (0.5 points)
#
# Create a function that receives a sentence as input and prints the histogram of letter frequencies. For example, for the input `hello world`, the program should print:
#
# ```
# h : *
# e : *
# l : ***
# o : **
# w : *
# r : *
# d : *
# ```

# %%
# Write your code here

# %%
# Test your code here
# Example: your_function('hello world')

# %% [markdown]
# ## Question 3 (1.5 points)
#
# Write a program that multiplies two matrices using **nested loops**. The matrices are given as lists of lists (provided in the cell below). Your program should print:
#
# ```
# [20, 7, 5]
# [13, 3, 31]
# [-9, 48, 2]
# ```
#
# Matrix multiplication is defined as:
#
# $$ result[i][j] = \sum_{k} A[i][k] \times B[k][j] $$
#
# **Hint:** start with a 3x3 matrix filled with zeros and fill each value using nested `for` loops.

# %%
A = [
    [2, -1, 3],
    [0, 4, 5],
    [7, 2, -2],
]
B = [
    [1, 6, 0],
    [-3, 2, 4],
    [5, -1, 3],
]

# Write your code here

# %% [markdown]
# You can check your result with NumPy:

# %%
import numpy as np
print(np.matmul(np.array(A), np.array(B)))

# %% [markdown]
# ## Question 4 (2.5 points)
#
# Run the cell below to load `countries-data.json` into a variable called `data`. `data` is a list of dictionaries, one per country, each with `name`, `capital`, `languages`, `population`, `flag`, and `currency`. Then answer parts (a) to (d), each in its own cell.

# %%
import json
with open(f"{REPO}/Assignments/countries-data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print('Loaded', len(data), 'countries')

# %% [markdown]
# ### Part (a) — How many different languages are in the data? Print a list of the languages.

# %%
# Write your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ### Part (b) — Find the ten most spoken languages. How many countries speak each one?

# %%
# Write your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ### Part (c) — Which country or countries speak the most languages? Identify the country (or countries) and the languages.

# %%
# Write your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ### Part (d) — Find the ten most populated countries in the world.

# %%
# Write your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*
