# %% [markdown]
# # APK 6725 — AI for Sport & Movement Sciences
# ## Assignment 1: Introduction to Python – Part I
#
# Work through each question below. Write your explanations in the markdown answer cells and your code in the code cells.

# %% [markdown]
# ## If working in Google Colab, Run this first
# Run the cell below, at the start of every session.
# It downloads the course files to your Google Drive and keeps them up to date.
# When you see \"Setup complete\", you are ready to run the rest of the notebook.
#
# **Do not edit or save your work inside the `AIforMovementScience` folder.**
# Use **File > Save a copy in Drive** and work on your own copy.

# %%
# [course-setup] Run this cell first, every session (or use Runtime > Run all)
import os
os.chdir('/content')                      # start from a valid directory
from google.colab import drive
drive.mount('/content/drive')

REPO = '/content/drive/MyDrive/AIforMovementScience'
if os.path.isdir(REPO + '/.git'):
    # already downloaded before: just update it
    # !git -C "$REPO" fetch origin main && git -C "$REPO" reset --hard origin/main
else:
    # first time, or a broken/partial copy: download a fresh copy
    # !rm -rf "$REPO"
    # !git clone https://github.com/dguari1/AIforMovementScience.git "$REPO"

os.chdir(REPO)
print('Setup complete. You can now run the rest of the notebook.')

# %% [markdown]
# ## How to submit
#
# Before you submit, please make sure your notebook is organized and reproducible. Part of your grade is for this.
#
# - Answer each question in its own section, using the headings already provided.
# - Write explanations in the **markdown** answer cells and put code in the **code** cells.
# - Before submitting, run **Runtime > Restart session and run all**. Your notebook must run from top to bottom with no errors, and all outputs must be visible.
# - Delete any scratch or experimental cells that are not part of your answer.
# - Download your notebook: **File > Download > Download .ipynb**, name it `YourName_Assignment_1.ipynb`, and upload it to Canvas.

# %% [markdown]
# ## Question 1
#
# In the code cell below, print the sentence:
#
# > I love learning Python

# %%
# Your code here

# %% [markdown]
# ## Question 2
#
# Compute the following expression, then explain the result in the answer cell.
#
# ```
# 4 + 5 * 3 - 6 / 2
# ```
#
# _Hint: search for "Python operator precedence"._

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ## Question 3
#
# Modify the expression from Question 2 by adding **one** set of parentheses so that the result is `-3.5`. Explain your change in the answer cell.

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ## Question 4
#
# Use the `math` or `numpy` library to compute the **sine of 90 degrees**. The result should be `1`.
#
# _Hint: the sine function expects radians, so convert 90 degrees to radians first._

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ## Question 5
#
# The hyperbolic sine is defined in terms of exponentials as
#
# $$\sinh(x) = \frac{e^{x} - e^{-x}}{2}$$
#
# Compute $\sinh(x)$ for $x = 2$ using exponentials. Then verify your result using the built-in function (for example, `math.sinh(2)`), and confirm in the answer cell that the two match.

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ## Question 6
#
# Compute the following expression:
#
# $$e^{2}\,\sin(\pi/6) + \log_e(3)\,\cos(\pi/9) - 5^{3}$$

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ## Question 7
#
# The file `file.txt` (in the `Assignments` folder of the course repository) contains a list of numbers. First, run the cell below to load the numbers into a variable called `mylist`. Then answer parts (a) to (d), each in its own code cell, and write each answer in the markdown cell.

# %%
# file.txt is in the Assignments folder of the course repository
# if loading from a local copy of the repository, change the path to the file accordingly
file = open(f'{REPO}/Assignments/file.txt', 'r')
data = file.read()
ls = data.split('\n')
ls.pop()
mylist = [eval(i) for i in ls]
file.close()

print('Loaded the following list:', mylist)

# %% [markdown]
# ### Part (a) — How many elements are in the list?

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ### Part (b) — What are the largest and smallest numbers in the list?

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ### Part (c) — What is the sum of the 10 largest numbers?
#
# _Hint: you can add the elements of a list with `sum()`._

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*

# %% [markdown]
# ### Part (d) — Are there any repeated numbers in the list?

# %%
# Your code here

# %% [markdown]
# **Your answer:**  *(double-click this cell to write your answer)*
