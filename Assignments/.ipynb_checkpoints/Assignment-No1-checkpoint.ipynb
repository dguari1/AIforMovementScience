# %% [markdown]
# # APK 4720 / APK 6725
#
# # Assignment # 1
#
# Please submit your assignment as a Jupyter (.ipynb) or PDF file
#
# 1) Start a new Jupyter notebook and name it "YourName_Assignment_1.ipynb"
#
# Replace *YourName* with your first name and last name
#
# 2) In a new cell print
# ``` python
# I love learning Python
# ```
#
#
# 3) Compute the following expressions
# ``` python
# 4 + 5 * 3 - 6 / 2
# ```
#
# Briefly explain the result of this operation.
#
# Hint: Google ***Python Operator Precedence***
#
# 4) Modify the previous expression by adding a set of parentheses '( )' so that the result of the operation is `-3.5`. Briefly explain your results
#
# 5) Use the math or numpy library to compute the $sine$ of $90$ degrees.
#
# Hint: The input to the sin function should be in radians, so you need to transform $90$ degrees to radians.
# The output should be 1.
#
# 6) The hyperbolic $\sin$ or `sinh` is defined in terms of exponentials as
# $$
# \sinh(x)=\frac{\exp(x)−\exp(−x)}{2}.
# $$
#
# Compute $\sinh(x)$ for $x=2$ using exponentials. Verify that the result is indeed the hyperbolic $sin$ using Python’s function $sinh$ in the math or numpy libraries as follows:
# ```Python
# import math
# math.sinh(2)
# ```
#
# 7) Compute the following expression
# $$
# e^2 \sin(\pi/6) + log_e(3)\cos(\pi/9)-5^3
# $$
#
# 8) Load the data provided in `file.txt` in a variable (`mylist`) using the following code:
# ```Python
# file = open("file.txt", "r")
# data = file.read()
# ls = data.split("\n")
# ls.pop()
# mylist = [eval(i) for i in ls]
# file.close()
# ```
#
# Hint: The file must be in the same folder as your Jupyter notebook, or you must provide the absolute path for the file.
#
# a. How many elements are in the list?
#
# b. What are the largest and smallest numbers of the list?
#
# c. What is the sum of the 10 largest numbers in the list? (you can use `sum()` to add elements in a list)
#
# d. Are there any repeated numbers in the list?
