# %% [markdown]
# # APK 4720 / APK 6725
#
# # Assignment # 3
#
# Please submit your assignment as a Jupyter  notebook (.ipynb file). Start a new Jupyter notebook and name it "YourName_Assignment_3"
#
# Replace *YourName* with your first name and last name
#
#
# Description: This assignment will assess your ability to use loops to solve programming challenges. Some of the points will also require the use of lists/dictionaries to complete the task.
#
#
# 1. [0.5 points] Create a function that prints the following pattern for a given input `n`.
#
# For instance, for `n=5` it should print
# ```python
# 1
# 22
# 333
# 4444
# 55555
# 4444
# 333
# 22
# 1
# ```
#
# 3. [0.5 point] Create a function that receives a sentence as input and prints the histogram of letter frequencies. For example, for the input `hello world`, the program should print
# ```
# h : *
# e : *
# l : **
# o : **
# w : *
# r : *
# d : *
# ```
#
#
# 2. [1.5 points] Write a Python program that multiplies two matrices using nested loops. For instance, given the following matrices created as a list of lists,
#
# ```python
# A = [
#     [2, -1, 3],
#     [0, 4, 5],
#     [7, 2, -2]
# ]
#
# B = [
#     [1, 6, 0],
#     [-3, 2, 4],
#     [5, -1, 3]
# ]
# ```
#
# your program should print
# ```python
# [20, 7, 5]
# [13, 3, 31]
# [-9, 48, 2]
# ```
#
# Remember that matrix multiplication is given by the formula
# $$
# result[i][j] = \sum_{k}A[i][k] \times B[k][j]
# $$
#
# Hint: Start with a 3x3 matrix filled with zeros and replace each value of the matrix using nested for loops.
#
# You can verify the result using
# ```python
# import numpy as np
# print(np.matmul(np.array(A), np.array(B)))
# ```
#
# 4. [2.5 points] Load the provided *json* file into a variable using the following code
# ```python
# import json
# f = open('countries-data.json')
# data = json.load(f)
# ```
#
# make sure that the file *countries-data.json* is in the same folder as your jupyter notebook. The variable ```data``` is a list of dictionaries, and each dictionary contains information about different countries in the world.
#     The data includes:
#     - name
#     - capital
#     - languages
#     - population
#     - flag
#     - currency
#
#  a. How many different languages are the data? Print a list of the languages.
#
#  b. Find the ten most spoken languages from the data. How many countries speak each language?
#
#  c. What country or countries speak the most languages? Identify the country or countries and the languages.
#
#  d. Find the 10 most populated countries in the world.
