# %% [markdown]
# # APK 4720 / APK 6725
#
# # Assignment # 4
#
# Please submit your assignment as a Jupyter  notebook (.ipynb file). Start a new Jupyter notebook and name it "YourName_Assignment_3"
#
# Replace *YourName* with your first name and last name

# %%
data = pd.read_csv('column_3C_weka.csv', index_col=None)
data.pop('degree_spondylolisthesis')
data.pop('class')
# Out:
# 0      Hernia
# 1      Hernia
# 2      Hernia
# 3      Hernia
# 4      Hernia
#         ...
# 305    Normal
# 306    Normal
# 307    Normal
# 308    Normal
# 309    Normal
# Name: class, Length: 310, dtype: object

# %%
data.to_csv('assigment4.csv', index=None)
