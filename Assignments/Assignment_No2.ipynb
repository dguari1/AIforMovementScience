# %% [markdown]
# # APK 6725 — AI for Sport & Movement Sciences
# ## Assignment 2: Introduction to Python – Part II (Functions)
#
# This assignment assesses your ability to use **functions** to solve programming problems. Some questions also use lists or dictionaries. Write each function in the code cell provided and test it below.

# %% [markdown]
# ## If working in Google Colab, Run this first
# Run the cell below, at the start of every session.
# It downloads the course files to your Google Drive and keeps them up to date.
# When you see \"Setup complete\", you are ready to run the rest of the notebook.
#
# **Do not edit or save your work inside the `AIforMovementScience` folder.**
# Use **File > Save a copy in Drive** and work on your own copy.

# %%
# [course-setup] Run this cell first, every session (or use Runtime > Run all)
import os, sys
os.chdir('/content')                      # start from a valid directory
from google.colab import drive
drive.mount('/content/drive')

REPO = '/content/drive/MyDrive/AIforMovementScience'
if os.path.isdir(REPO + '/.git'):
    # already downloaded before: just update it
    # !git -C "$REPO" fetch origin main && git -C "$REPO" reset --hard origin/main
else:
    # first time, or a broken/partial copy: download a fresh copy
    # !rm -rf "$REPO"
    # !git clone https://github.com/dguari1/AIforMovementScience.git "$REPO"

WORKDIR = REPO + '/lectures'          # this notebook's folder in the course files
os.chdir(WORKDIR)
sys.path.insert(0, WORKDIR)           # so local .py files (e.g. FunctionExamples.py) import correctly
print('Setup complete. You can now run the rest of the notebook.')

# %% [markdown]
# ## How to submit
#
# Before you submit, please make sure your notebook is organized and reproducible. Part of your grade is for this.
#
# - Answer each question in its own section, using the headings already provided.
# - Write your function in the code cell, and test it in the test cell below it so the output is visible.
# - Delete any scratch or experimental cells that are not part of your answer.
# - Download your notebook: **File > Download > Download .ipynb**, name it `YourName_Assignment_2.ipynb`, and upload it to Canvas.

# %% [markdown]
# ## Question 1 (1 point)
#
# Write a function with one input, a **string**. Words in the string are separated by a space `' '`. Your function should return:
# - the number of words in the sentence,
# - the number of characters in the sentence (excluding spaces),
# - a dictionary with the frequency of each letter in the sentence.
#
# **Do not use loops.** Ignore punctuation and capitalization.
#
# **Hints**
#
# - You can split a string on a separator:
# ```python
# text = 'Hi how are you?'
# parts = text.split(' ')
# print(parts)   # ['Hi', 'how', 'are', 'you?']
# ```
# - Python has a library for counting hashable objects efficiently:
# ```python
# from collections import Counter
# ```
# - For the input `Hello World`, the output should be:
# ```
# Words: 2
# Characters: 10
# Letter frequency: {'h':1,'e':1,'l':3,'o':2,'w':1,'r':1,'d':1}
# ```

# %%
# Write your function here

# %%
# Test your function here
# Example: your_function('Hello World')

# %% [markdown]
# ## Question 2 (2 points)
#
# Write a function with one input, a **string**. Words are separated by a space `' '`. Your function should identify whether there are numbers in the sentence. If there are numbers, the function must return their **sum**.
#
# **Examples**
#
# ```
# Input:  'There are 3 friends with me, 2 of us are older than 18'
# Output: 23
# ```
# ```
# Input:  'My online friend, XX_SAM2000_XX is turning 18 next week'
# Output: 2018
# ```
#
# **Hint:** Don't use loops, instead, Python has a standard library for searching patterns inside text, called `re`. Investigate how to load and use `re` to solve this problem.

# %%
# Write your function here

# %%
# Test your function here
# Example: your_function('There are 3 friends with me, 2 of us are older than 18')

# %% [markdown]
# ## Question 3 (2 points)
#
# Write a function with one input: a **string** representing a date in the format month (two digits) / day (two digits) / year (four digits). The function should first check that the date is valid, for example:
#
# - `01/20/1985` -> valid
# - `02/30/2022` -> not valid (February does not have 30 days)
# - `15/12/2000` -> not valid (month 15 does not exist)
#
# If the date is valid, the function should return the number of days from that date until **today**.
#
# **Hints**
#
# - You can get today's date with:
# ```python
# from datetime import date
# today = date.today()
# ```
# - Subtracting two `date` objects gives the number of days between them.
# - A leap year (February has 29 days instead of 28) is divisible by four.

# %%
# Write your function here

# %%
# Test your function here
# Example: your_function('01/20/1985')
